# %% [markdown]
# # 01 — Data Cleaning
#
# This notebook performs data-quality checks and creates a reproducible cleaned dataset.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.data_cleaning import load_data, clean_airbnb_data, save_data

RAW_PATH = PROJECT_ROOT / "data" / "raw" / "AB_NYC_2019.csv"
CLEAN_PATH = PROJECT_ROOT / "data" / "processed" / "airbnb_nyc_cleaned.csv"

# %%
df = load_data(RAW_PATH)
print(f"Rows: {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
df.head()

# %% [markdown]
# ## Data-quality checks

# %%
quality_report = pd.DataFrame({
    "dtype": df.dtypes.astype(str),
    "missing_values": df.isna().sum(),
    "missing_pct": (df.isna().mean() * 100).round(2),
    "unique_values": df.nunique()
}).sort_values("missing_pct", ascending=False)

quality_report

# %%
print(f"Duplicate rows: {df.duplicated().sum():,}")

# %% [markdown]
# ## Cleaning

# %%
cleaned_df = clean_airbnb_data(df)

print(f"Rows before cleaning: {len(df):,}")
print(f"Rows after cleaning:  {len(cleaned_df):,}")
cleaned_df.head()

# %%
save_data(cleaned_df, CLEAN_PATH)
print(f"Saved cleaned dataset to: {CLEAN_PATH}")
